# %% [markdown]
# # Using R on the DataDashboard

# %% [markdown]
# ## Note: Currently database connectivity not directly available on R through Jupyter

# %% [markdown]
# To run this example, make sure [db-connect](../python/db-connect.ipynb) has been run and the data frame has been saved to this directory (run the next cell to make sure).

# %%
file_in = "persistent.csv"

# %%
df = read.csv(file_in)
df
# Out:
#        X   id                             hash             created
# 1      0    1 d0f9bec4175fa0cd8738bdac9b5aaad4 2012-09-28 13:47:29
# 2      1    2 eba9524b6f55ece61f537e5be6bca0a8 2012-09-28 13:54:38
# 3      2    3 028b64e0c4aa92242dee62618daa466d 2012-09-28 13:57:00
# 4      3    4 420890de6d4502294404608684259c38 2012-09-28 13:58:58
# 5      4    5 96e4f672259a43fb729b43f771185983 2012-09-28 14:00:09
# 6      5    6 2ae0326e8c14225de2b289fb307ebc7b 2012-09-28 14:02:19
# 7      6    7 2cfabc6619277e8a2fc7222d963d8636 2012-09-28 14:04:39
# 8      7    8 d42fce44339a6483c22a430a0a74709f 2012-09-28 14:07:55
# 9      8    9 81728b805ec37c994ae2c5e596957bac 2012-09-28 14:08:25
# 10     9   10 501d0e7a44484ebe0fd0d42c7d6811a4 2012-09-28 14:11:46
# 11    10   11 e33c9a422ccb7109947dd0b6fb5c2c32 2012-09-28 14:18:39
# 12    11   12 d477528bd345fc53dc13cdd43803ee7f 2012-09-28 14:22:10
# 13    12   13 4ce366ff081a634f7d6a60dae1d9fef4 2012-09-28 14:24:46
# ...
